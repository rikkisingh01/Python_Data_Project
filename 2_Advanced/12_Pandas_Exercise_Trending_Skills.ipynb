# %%
# Importing Libraries
import ast
import pandas as pd
from datasets import load_dataset
import matplotlib.pyplot as plt  

# Loading Data
dataset = load_dataset('lukebarousse/data_jobs')
df = dataset['train'].to_pandas()

# Data Cleanup
df['job_posted_date'] = pd.to_datetime(df['job_posted_date'])
df['job_skills'] = df['job_skills'].apply(lambda x: ast.literal_eval(x) if pd.notna(x) else x)

# %%
#Filter the dataframe on Data Analyst and make a copy
df_DA = df[df['job_title_short'] == 'Data Analyst'].copy()

# %%
#Create a month no column in the dataframe
df_DA['job_posted_month_no'] = df_DA['job_posted_date'].dt.month

# %%
#Explode the 'job skills' and set to a new dataframe
df_DA_explode = df_DA.explode('job_skills')

#Check the new dataframe
df_DA_explode

# %%
#We will pivot on 'job_posted_month_no' and 'job_skills' with size being the agg
df_DA_explode.pivot_table(index='job_posted_month_no', columns='job_skills', aggfunc='size')
# Out:
# job_skills           airflow  airtable  alteryx  angular  angular.js  ansible  \
# job_posted_month_no
# 1                      197.0      17.0    551.0     63.0         2.0     20.0
# 2                      169.0       2.0    448.0     49.0         NaN     14.0
# 3                      181.0       4.0    442.0     34.0         NaN     23.0
# 4                      155.0       4.0    413.0     22.0         NaN     11.0
# 5                      128.0       8.0    310.0     30.0         NaN     19.0
# 6                      164.0      14.0    393.0     29.0         NaN     14.0
# 7                      207.0       4.0    366.0     15.0         NaN      8.0
# 8                      197.0       3.0    413.0     21.0         NaN     12.0
# 9                      118.0       4.0    317.0     21.0         NaN     14.0
# 10                     173.0      11.0    350.0     40.0         NaN     19.0
# 11                     169.0       7.0    293.0     24.0         NaN     19.0
# ...

# %%
#We need to handle the NaN. Since they are not there, they are 0.  We can use fill_value=0 
df_DA_explode.pivot_table(index='job_posted_month_no', columns='job_skills', aggfunc='size', fill_value=0)
# Out:
# job_skills           airflow  airtable  alteryx  angular  angular.js  ansible  \
# job_posted_month_no
# 1                        197        17      551       63           2       20
# 2                        169         2      448       49           0       14
# 3                        181         4      442       34           0       23
# 4                        155         4      413       22           0       11
# 5                        128         8      310       30           0       19
# 6                        164        14      393       29           0       14
# 7                        207         4      366       15           0        8
# 8                        197         3      413       21           0       12
# 9                        118         4      317       21           0       14
# 10                       173        11      350       40           0       19
# 11                       169         7      293       24           0       19
# ...

# %%
#Set the pivot table to a new variable
df_DA_pivot = df_DA_explode.pivot_table(index='job_posted_month_no', columns='job_skills', aggfunc='size', fill_value=0)

df_DA_pivot
# Out:
# job_skills           airflow  airtable  alteryx  angular  angular.js  ansible  \
# job_posted_month_no
# 1                        197        17      551       63           2       20
# 2                        169         2      448       49           0       14
# 3                        181         4      442       34           0       23
# 4                        155         4      413       22           0       11
# 5                        128         8      310       30           0       19
# 6                        164        14      393       29           0       14
# 7                        207         4      366       15           0        8
# 8                        197         3      413       21           0       12
# 9                        118         4      317       21           0       14
# 10                       173        11      350       40           0       19
# 11                       169         7      293       24           0       19
# ...

# %%
#Need to reduce the amount of skills to the top X because there are too many.  This means we need to create a total value
df_DA_pivot.loc['Total'] = df_DA_pivot.sum()

df_DA_pivot
# Out:
# job_skills           airflow  airtable  alteryx  angular  angular.js  ansible  \
# job_posted_month_no
# 1                        197        17      551       63           2       20
# 2                        169         2      448       49           0       14
# 3                        181         4      442       34           0       23
# 4                        155         4      413       22           0       11
# 5                        128         8      310       30           0       19
# 6                        164        14      393       29           0       14
# 7                        207         4      366       15           0        8
# 8                        197         3      413       21           0       12
# 9                        118         4      317       21           0       14
# 10                       173        11      350       40           0       19
# 11                       169         7      293       24           0       19
# ...

# %%
#Now that we have the total column we can sort the pivot. Like filtereing on a dataframe within the dataframe: df[df[filter]]:
df_DA_pivot = df_DA_pivot[df_DA_pivot.loc['Total'].sort_values(ascending=False).index]

df_DA_pivot
# Out:
# job_skills             sql  excel  python  tableau  power bi      r    sas  \
# job_posted_month_no
# 1                    11336   8170    6606     5596      4285   3607   3830
# 2                     7947   5772    4751     3936      3307   2576   2634
# 3                     7868   5675    4741     4051      3176   2650   2554
# 4                     7553   5496    4557     3776      3106   2399   2598
# 5                     6617   4773    4070     3245      2695   2093   1940
# 6                     7584   5724    4707     3812      3275   2442   2174
# 7                     7687   5513    4831     3928      3350   2444   2118
# 8                     8823   6482    5576     4533      3859   2975   2560
# 9                     6829   4886    4229     3446      3118   2146   1880
# 10                    7474   5217    4693     3709      3340   2380   2114
# 11                    6652   4776    4233     3284      3012   2159   1738
# ...

# %%
#Now we need to drop the total row we added so it does not impact the graph. We just added it for sorting purposes
df_DA_pivot = df_DA_pivot.drop('Total')

df_DA_pivot
# Out:
# job_skills             sql  excel  python  tableau  power bi     r   sas  \
# job_posted_month_no
# 1                    11336   8170    6606     5596      4285  3607  3830
# 2                     7947   5772    4751     3936      3307  2576  2634
# 3                     7868   5675    4741     4051      3176  2650  2554
# 4                     7553   5496    4557     3776      3106  2399  2598
# 5                     6617   4773    4070     3245      2695  2093  1940
# 6                     7584   5724    4707     3812      3275  2442  2174
# 7                     7687   5513    4831     3928      3350  2444  2118
# 8                     8823   6482    5576     4533      3859  2975  2560
# 9                     6829   4886    4229     3446      3118  2146  1880
# 10                    7474   5217    4693     3709      3340  2380  2114
# 11                    6652   4776    4233     3284      3012  2159  1738
# 12                    6058   4376    4196     3139      2857  2125  1858
# ...

# %%
#We can now plot using iloc. We want all the rows and only the first 5 columns:
df_DA_pivot.iloc[:, :5].plot(kind='line')
plt.title('Top 5 skills for Data Analyst per Month')
plt.ylabel('Count')
plt.xlabel('')
plt.show()
